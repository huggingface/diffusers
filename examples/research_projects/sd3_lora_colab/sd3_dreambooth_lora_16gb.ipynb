# %% [markdown]
# # Running Stable Diffusion 3 (SD3) DreamBooth LoRA training under 16GB GPU VRAM

# %% [markdown]
# ## Install Dependencies

# %%
# !pip install -q -U git+https://github.com/huggingface/diffusers
# !pip install -q -U \
    transformers \
    accelerate \
    wandb \
    bitsandbytes \
    peft
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 6.3 MB/s eta 0:00:00

# %% [markdown]
# As SD3 is gated, before using it with diffusers you first need to go to the [Stable Diffusion 3 Medium Hugging Face page](https://huggingface.co/stabilityai/stable-diffusion-3-medium-diffusers), fill in the form and accept the gate. Once you are in, you need to log in so that your system knows you’ve accepted the gate. Use the command below to log in:

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ## Clone `diffusers`

# %%
# TODO: change the branch when PR is merged.
# !git clone -b colab-sd3-lora https://github.com/huggingface/diffusers
# %cd diffusers/examples/research_projects/sd3_lora_colab
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 65624, done.
# remote: Counting objects: 100% (171/171), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 65624 (delta 73), reused 90 (delta 23), pack-reused 65453
# Receiving objects: 100% (65624/65624), 48.07 MiB | 13.92 MiB/s, done.
# Resolving deltas: 100% (48303/48303), done.
# /content/diffusers/examples/research_projects/sd3_lora_colab

# %% [markdown]
# ## Download instance data images

# %%
from huggingface_hub import snapshot_download

local_dir = "./dog"
snapshot_download(
    "diffusers/dog-example",
    local_dir=local_dir, repo_type="dataset",
    ignore_patterns=".gitattributes",
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# alvan-nee-9M0tSjb-cpA-unsplash.jpeg:   0%|          | 0.00/677k [00:00<?, ?B/s]
# alvan-nee-Id1DBHv4fbg-unsplash.jpeg:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# alvan-nee-brFsZ7qszSY-unsplash.jpeg:   0%|          | 0.00/1.19M [00:00<?, ?B/s]
# alvan-nee-eoqnr8ikwFE-unsplash.jpeg:   0%|          | 0.00/1.17M [00:00<?, ?B/s]
# alvan-nee-bQaAJCbNq3g-unsplash.jpeg:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# '/content/diffusers/examples/research_projects/sd3_lora_colab/dog'

# %%
# !rm -rf dog/.huggingface

# %% [markdown]
# ## Compute embeddings
#
# Here we are using the default instance prompt "a photo of sks dog". But you can configure this. Refer to the `compute_embeddings.py` script for details on other supported arguments.

# %%
# !python compute_embeddings.py
# Out:
# 2024-07-02 02:24:38.371939: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-02 02:24:38.372003: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-02 02:24:38.391491: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-02 02:24:38.408259: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-02 02:24:40.093752: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Downloading shards: 100% 2/2 [00:00<00:00, 7244.05it/s]
# Loading checkpoint shards: 100% 2/2 [00:39<00:00, 19.73s/it]
# Loading pipeline components...:  43% 3/7 [00:08<00:11,  2.83s/it]You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# Loading pipeline components...: 100% 7/7 [00:08<00:00,  1.21s/it]
# prompt_embeds.shape=torch.Size([1, 154, 4096]), negative_prompt_embeds.shape=torch.Size([1, 154, 4096]), pooled_prompt_embeds.shape=torch.Size([1, 2048]), torch.Size([1, 2048])
# Max memory allocated: 10.552 GB
# Number of images: 5.
# Data successfully serialized to sample_embeddings.parquet

# %% [markdown]
# ## Clear memory

# %%
import torch
import gc


def flush():
    torch.cuda.empty_cache()
    gc.collect()

flush()

# %% [markdown]
# ## Train!

# %%
# !accelerate launch train_dreambooth_lora_sd3_miniature.py \
  --pretrained_model_name_or_path="stabilityai/stable-diffusion-3-medium-diffusers"  \
  --instance_data_dir="dog" \
  --data_df_path="sample_embeddings.parquet" \
  --output_dir="trained-sd3-lora-miniature" \
  --mixed_precision="fp16" \
  --instance_prompt="a photo of sks dog" \
  --resolution=1024 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 --gradient_checkpointing \
  --use_8bit_adam \
  --learning_rate=1e-4 \
  --report_to="wandb" \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_train_steps=500 \
  --seed="0"
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2024-07-02 02:28:10.181877: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-02 02:28:10.181930: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-02 02:28:10.283744: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-02 02:28:10.483166: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-02 02:28:12.674841: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 07/02/2024 02:28:16 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# wandb: Currently logged in as: sayakpaul. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.3
# wandb: Run data is saved locally in /content/diffusers/examples/research_projects/sd3_lora_colab/wandb/run-20240702_022847-8u86juft
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run unique-sun-12
# wandb: ⭐️ View project at https://wandb.ai/sayakpaul/dreambooth-sd3-lora-miniature
# wandb: 🚀 View run at https://wandb.ai/sayakpaul/dreambooth-sd3-lora-miniature/runs/8u86juft
# 07/02/2024 02:28:48 - INFO - __main__ - ***** Running training *****
# 07/02/2024 02:28:48 - INFO - __main__ -   Num examples = 5
# 07/02/2024 02:28:48 - INFO - __main__ -   Num batches each epoch = 5
# 07/02/2024 02:28:48 - INFO - __main__ -   Num Epochs = 250
# 07/02/2024 02:28:48 - INFO - __main__ -   Instantaneous batch size per device = 1
# 07/02/2024 02:28:48 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 4
# 07/02/2024 02:28:48 - INFO - __main__ -   Gradient Accumulation steps = 4
# 07/02/2024 02:28:48 - INFO - __main__ -   Total optimization steps = 500
# Steps: 100% 500/500 [1:13:05<00:00,  7.83s/it, loss=0.0331, lr=0.0001]07/02/2024 03:41:54 - INFO - accelerate.accelerator - Saving current state to trained-sd3-lora-miniature/checkpoint-500
# Model weights saved in trained-sd3-lora-miniature/checkpoint-500/pytorch_lora_weights.safetensors
# 07/02/2024 03:41:55 - INFO - accelerate.checkpointing - Optimizer state saved in trained-sd3-lora-miniature/checkpoint-500/optimizer.bin
# 07/02/2024 03:41:55 - INFO - accelerate.checkpointing - Scheduler state saved in trained-sd3-lora-miniature/checkpoint-500/scheduler.bin
# 07/02/2024 03:41:55 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in trained-sd3-lora-miniature/checkpoint-500/sampler.bin
# 07/02/2024 03:41:55 - INFO - accelerate.checkpointing - Gradient scaler state saved in trained-sd3-lora-miniature/checkpoint-500/scaler.pt
# 07/02/2024 03:41:55 - INFO - accelerate.checkpointing - Random states saved in trained-sd3-lora-miniature/checkpoint-500/random_states_0.pkl
# 07/02/2024 03:41:55 - INFO - __main__ - Saved state to trained-sd3-lora-miniature/checkpoint-500
# Steps: 100% 500/500 [1:13:06<00:00,  7.83s/it, loss=0.035, lr=0.0001] Model weights saved in trained-sd3-lora-miniature/pytorch_lora_weights.safetensors
#
# Loading pipeline components...:   0% 0/9 [00:00<?, ?it/s]
#
# Loading checkpoint shards:   0% 0/2 [00:00<?, ?it/s]
#
# Loading checkpoint shards:  50% 1/2 [00:05<00:05,  5.48s/it]
#
# Loading checkpoint shards: 100% 2/2 [00:11<00:00,  5.55s/it]
# Loaded text_encoder_3 as T5EncoderModel from `text_encoder_3` subfolder of stabilityai/stable-diffusion-3-medium-diffusers.
#
# Loading pipeline components...:  11% 1/9 [00:11<01:29, 11.18s/it]Loaded text_encoder as CLIPTextModelWithProjection from `text_encoder` subfolder of stabilityai/stable-diffusion-3-medium-diffusers.
#
# Loading pipeline components...:  22% 2/9 [00:11<00:34,  4.99s/it]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of stabilityai/stable-diffusion-3-medium-diffusers.
# Loaded scheduler as FlowMatchEulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-3-medium-diffusers.
# Loaded text_encoder_2 as CLIPTextModelWithProjection from `text_encoder_2` subfolder of stabilityai/stable-diffusion-3-medium-diffusers.
#
# Loading pipeline components...:  56% 5/9 [00:13<00:07,  1.77s/it]You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# Loaded tokenizer_3 as T5TokenizerFast from `tokenizer_3` subfolder of stabilityai/stable-diffusion-3-medium-diffusers.
#
# Loading pipeline components...:  67% 6/9 [00:13<00:04,  1.42s/it]Loaded vae as AutoencoderKL from `vae` subfolder of stabilityai/stable-diffusion-3-medium-diffusers.
#
# Loading pipeline components...:  78% 7/9 [00:14<00:02,  1.13s/it]Loaded tokenizer_2 as CLIPTokenizer from `tokenizer_2` subfolder of stabilityai/stable-diffusion-3-medium-diffusers.
#
# Loading pipeline components...:  89% 8/9 [00:14<00:00,  1.18it/s]Loaded transformer as SD3Transformer2DModel from `transformer` subfolder of stabilityai/stable-diffusion-3-medium-diffusers.
#
# Loading pipeline components...: 100% 9/9 [00:18<00:00,  2.04s/it]
# wandb:
# wandb: W&B sync reduced upload amount by 11.7%
# wandb:
# wandb: Run history:
# wandb: loss ▄▃▃▃▂▄▄▁▃▂▂▅▃▂▂▃▃▄▃▂▂▃▂▅▁▃▂▆▂▂▂▃█▃▄▃▂▂▃▃
# wandb:   lr ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb: loss 0.03501
# wandb:   lr 0.0001
# wandb:
# wandb: 🚀 View run unique-sun-12 at: https://wandb.ai/sayakpaul/dreambooth-sd3-lora-miniature/runs/8u86juft
# wandb: ⭐️ View project at: https://wandb.ai/sayakpaul/dreambooth-sd3-lora-miniature
# wandb: Synced 6 W&B file(s), 0 media file(s), 3 artifact file(s) and 1 other file(s)
# wandb: Find logs at: ./wandb/run-20240702_022847-8u86juft/logs
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py:2310: UserWarning: Run (8u86juft) is finished. The call to `_console_raw_callback` will be ignored. Please make sure that you are using an active run.
#   lambda data: self._console_raw_callback("stderr", data),
# Steps: 100% 500/500 [1:13:34<00:00,  8.83s/it, loss=0.035, lr=0.0001]

# %% [markdown]
# Training will take about an hour to complete depending on the length of your dataset.

# %% [markdown]
# ## Inference

# %%
flush()

# %%
from diffusers import DiffusionPipeline
import torch

pipeline = DiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-3-medium-diffusers",
    torch_dtype=torch.float16
)
lora_output_path = "trained-sd3-lora-miniature"
pipeline.load_lora_weights("trained-sd3-lora-miniature")

pipeline.enable_sequential_cpu_offload()

image = pipeline("a photo of sks dog in a bucket").images[0]
image.save("bucket_dog.png")

# %% [markdown]
# Note that inference will be very slow in this case because we're loading and unloading individual components of the models and that introduces significant data movement overhead. Refer to [this resource](https://huggingface.co/blog/sd3#memory-optimizations-for-sd3) for more memory optimization related techniques.
